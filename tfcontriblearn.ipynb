# %% [markdown]
# ### tf.contrib.learn
# * running training loops
# * running evaluation loops
# * managing data sets
# * managing feeding

# %%
import tensorflow as tf
# NumPy is often used to load, manipulate and preprocess data.
import numpy as np

# Declare list of features. We only have one real-valued feature. There are many
# other types of columns that are more complicated and useful.
features = [tf.contrib.layers.real_valued_column("x", dimension=1)]

# An estimator is the front end to invoke training (fitting) and evaluation
# (inference). There are many predefined types like linear regression,
# logistic regression, linear classification, logistic classification, and
# many neural network classifiers and regressors. The following code
# provides an estimator that does linear regression.
estimator = tf.contrib.learn.LinearRegressor(feature_columns=features)

# TensorFlow provides many helper methods to read and set up data sets.
# Here we use `numpy_input_fn`. We have to tell the function how many batches
# of data (num_epochs) we want and how big each batch should be.
x = np.array([1., 2., 3., 4.])
y = np.array([0., -1., -2., -3.])
input_fn = tf.contrib.learn.io.numpy_input_fn({"x":x}, y, batch_size=4,
                                              num_epochs=1000)

# We can invoke 1000 training steps by invoking the `fit` method and passing the
# training data set.
estimator.fit(input_fn=input_fn, steps=1000)

# Here we evaluate how well our model did. In a real example, we would want
# to use a separate validation and testing data set to avoid overfitting.
print(estimator.evaluate(input_fn=input_fn))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_tf_random_seed': None, '_keep_checkpoint_max': 5, '_task_id': 0, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_save_summary_steps': 100, '_evaluation_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000000A669D23F28>, '_task_type': None, '_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_master': '', '_environment': 'local', '_num_worker_replicas': 0, '_is_chief': True, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': None}
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\grass\AppData\Local\Temp\tmpgi4ooxjd
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:From d:\sf\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\grass\AppData\Local\Temp\tmpgi4ooxjd\model.ckpt.
# INFO:tensorflow:loss = 3.5, step = 1
# INFO:tensorflow:global_step/sec: 670.665
# INFO:tensorflow:loss = 0.0407462, step = 101 (0.138 sec)
# INFO:tensorflow:global_step/sec: 1175.64
# INFO:tensorflow:loss = 0.0186874, step = 201 (0.085 sec)
# INFO:tensorflow:global_step/sec: 1142.05
# INFO:tensorflow:loss = 0.00183972, step = 301 (0.087 sec)
# INFO:tensorflow:global_step/sec: 1135.55
# INFO:tensorflow:loss = 0.000486383, step = 401 (0.089 sec)
# INFO:tensorflow:global_step/sec: 1249.12
# INFO:tensorflow:loss = 2.11541e-05, step = 501 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1289.41
# INFO:tensorflow:loss = 1.51137e-05, step = 601 (0.076 sec)
# INFO:tensorflow:global_step/sec: 1129.15
# INFO:tensorflow:loss = 1.95192e-06, step = 701 (0.089 sec)
# INFO:tensorflow:global_step/sec: 1378.31
# INFO:tensorflow:loss = 4.12723e-07, step = 801 (0.072 sec)
# INFO:tensorflow:global_step/sec: 1665.5
# INFO:tensorflow:loss = 8.70741e-08, step = 901 (0.061 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\grass\AppData\Local\Temp\tmpgi4ooxjd\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.62363e-08.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:From d:\sf\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-04-30-11:04:03
# INFO:tensorflow:Restoring parameters from C:\Users\grass\AppData\Local\Temp\tmpgi4ooxjd\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-04-30-11:04:04
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 1.32856e-08
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# {'loss': 1.328561e-08, 'global_step': 1000}

# %%
import tensorflow as tf 
import numpy as np

features=[tf.contrib.layers.real_valued_column("x",dimension=1)]
estimator=tf.contrib.learn.LinearRegressor(feature_columns=features)

x=np.array([1.0,2.0,3.0,4.0])
y=np.array([0.0,-1.0,-2.0,-3.0])

input_fn=tf.contrib.learn.io.numpy_input_fn({"x":x},y,batch_size=4,num_epochs=1000)
estimator.fit(input_fn=input_fn,steps=1000)
print(estimator.evaluate(input_fn=input_fn))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_tf_random_seed': None, '_keep_checkpoint_max': 5, '_task_id': 0, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_save_summary_steps': 100, '_evaluation_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000000A66F1E9198>, '_task_type': None, '_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_master': '', '_environment': 'local', '_num_worker_replicas': 0, '_is_chief': True, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': None}
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\grass\AppData\Local\Temp\tmp_9ojkxxl
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:From d:\sf\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\grass\AppData\Local\Temp\tmp_9ojkxxl\model.ckpt.
# INFO:tensorflow:loss = 1.75, step = 1
# INFO:tensorflow:global_step/sec: 1051.91
# INFO:tensorflow:loss = 0.0474923, step = 101 (0.097 sec)
# INFO:tensorflow:global_step/sec: 1068.76
# INFO:tensorflow:loss = 0.00205127, step = 201 (0.094 sec)
# INFO:tensorflow:global_step/sec: 1110.33
# INFO:tensorflow:loss = 0.00148272, step = 301 (0.091 sec)
# INFO:tensorflow:global_step/sec: 1116.52
# INFO:tensorflow:loss = 0.000125517, step = 401 (0.089 sec)
# INFO:tensorflow:global_step/sec: 1142.05
# INFO:tensorflow:loss = 8.24374e-05, step = 501 (0.088 sec)
# INFO:tensorflow:global_step/sec: 1129.15
# INFO:tensorflow:loss = 8.51148e-06, step = 601 (0.089 sec)
# INFO:tensorflow:global_step/sec: 1218.65
# INFO:tensorflow:loss = 1.72735e-06, step = 701 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1297.75
# INFO:tensorflow:loss = 2.73652e-07, step = 801 (0.077 sec)
# INFO:tensorflow:global_step/sec: 1427.58
# INFO:tensorflow:loss = 2.25019e-08, step = 901 (0.071 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\grass\AppData\Local\Temp\tmp_9ojkxxl\model.ckpt.
# INFO:tensorflow:Loss for final step: 3.08426e-09.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:From d:\sf\python35\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-04-30-11:17:43
# INFO:tensorflow:Restoring parameters from C:\Users\grass\AppData\Local\Temp\tmp_9ojkxxl\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-04-30-11:17:44
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 8.4095e-09
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# {'loss': 8.4095007e-09, 'global_step': 1000}

# %%
import numpy as np
import tensorflow as tf

# Model parameters
W = tf.Variable([.3], tf.float32)
b = tf.Variable([-.3], tf.float32)
# Model input and output
x = tf.placeholder(tf.float32)
linear_model = W * x + b
y = tf.placeholder(tf.float32)
# loss
loss = tf.reduce_sum(tf.square(linear_model - y)) # sum of the squares
# optimizer
optimizer = tf.train.GradientDescentOptimizer(0.01)
train = optimizer.minimize(loss)
# training data
x_train = [1,2,3,4]
y_train = [0,-1,-2,-3]
# training loop
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init) # reset values to wrong
for i in range(1000):
  sess.run(train, {x:x_train, y:y_train})

# evaluate training accuracy
curr_W, curr_b, curr_loss  = sess.run([W, b, loss], {x:x_train, y:y_train})
print("W: %s b: %s loss: %s"%(curr_W, curr_b, curr_loss))
# Out:
# W: [-0.9999969] b: [ 0.99999082] loss: 5.69997e-11

# %%
import numpy as np
import tensorflow as tf
# Declare list of features, we only have one real-valued feature
def model(features, labels, mode):
  # Build a linear model and predict values
  W = tf.get_variable("W", [1], dtype=tf.float64)
  b = tf.get_variable("b", [1], dtype=tf.float64)
  y = W*features['x'] + b
  # Loss sub-graph
  loss = tf.reduce_sum(tf.square(y - labels))
  # Training sub-graph
  global_step = tf.train.get_global_step()
  optimizer = tf.train.GradientDescentOptimizer(0.01)
  train = tf.group(optimizer.minimize(loss),
                   tf.assign_add(global_step, 1))
  # ModelFnOps connects subgraphs we built to the
  # appropriate functionality.
  return tf.contrib.learn.ModelFnOps(
      mode=mode, predictions=y,
      loss=loss,
      train_op=train)

estimator = tf.contrib.learn.Estimator(model_fn=model)
# define our data set
x = np.array([1., 2., 3., 4.])
y = np.array([0., -1., -2., -3.])
input_fn = tf.contrib.learn.io.numpy_input_fn({"x": x}, y, 4, num_epochs=1000)

# train
estimator.fit(input_fn=input_fn, steps=1000)
# evaluate our model
print(estimator.evaluate(input_fn=input_fn, steps=10))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_tf_random_seed': None, '_keep_checkpoint_max': 5, '_task_id': 0, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_save_summary_steps': 100, '_evaluation_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000000A670301BE0>, '_task_type': None, '_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_master': '', '_environment': 'local', '_num_worker_replicas': 0, '_is_chief': True, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': None}
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\grass\AppData\Local\Temp\tmphrxy_ekg
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\grass\AppData\Local\Temp\tmphrxy_ekg\model.ckpt.
# INFO:tensorflow:loss = 59.5463331114, step = 1
# INFO:tensorflow:global_step/sec: 1175.61
# INFO:tensorflow:loss = 0.237159400489, step = 101 (0.087 sec)
# INFO:tensorflow:global_step/sec: 1110.34
# INFO:tensorflow:loss = 0.0497812185, step = 201 (0.091 sec)
# INFO:tensorflow:global_step/sec: 1272.97
# INFO:tensorflow:loss = 0.00215391465445, step = 301 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1233.71
# INFO:tensorflow:loss = 0.000178506570407, step = 401 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1148.6
# INFO:tensorflow:loss = 1.12811191684e-05, step = 501 (0.088 sec)
# INFO:tensorflow:global_step/sec: 1297.79
# INFO:tensorflow:loss = 1.3527643014e-06, step = 601 (0.077 sec)
# INFO:tensorflow:global_step/sec: 1129.12
# INFO:tensorflow:loss = 6.26799199725e-08, step = 701 (0.088 sec)
# INFO:tensorflow:global_step/sec: 1480.44
# INFO:tensorflow:loss = 1.21253783467e-08, step = 801 (0.068 sec)
# INFO:tensorflow:global_step/sec: 1387.92
# INFO:tensorflow:loss = 2.16757247618e-10, step = 901 (0.073 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\grass\AppData\Local\Temp\tmphrxy_ekg\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.02574377898e-10.
# INFO:tensorflow:Starting evaluation at 2017-04-30-11:19:52
# INFO:tensorflow:Restoring parameters from C:\Users\grass\AppData\Local\Temp\tmphrxy_ekg\model.ckpt-1000
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2017-04-30-11:19:53
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 8.16274e-11
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# {'loss': 8.1627406e-11, 'global_step': 1000}
